# %% [markdown]
# Estoy desarrollando un trabajo académico para el curso **Metodologías de Diseño de Software**, basado en el caso de la empresa **EUROLOGISTIC**, la cual necesita desarrollar un nuevo sistema de información capaz de manejar más de 50,000 transacciones por segundo a nivel global.
#
# El proyecto requiere tomar decisiones estratégicas sobre qué tipo de metodologías de desarrollo aplicar. La empresa ha decidido optar por **metodologías tradicionales** en lugar de metodologías ágiles. El trabajo debe cumplir una **rúbrica académica detallada**, e incluir justificación técnica y fundamentación basada en ingeniería de software.
#
# A continuación, necesito que me ayudes en los siguientes puntos con enfoque académico y terminología técnica:
#
# ---
#
# ## ✅ Lo que necesito desarrollar
#
# 1. **Explica y desarrolla 7 razones clave por las que se eligieron metodologías tradicionales en lugar de ágiles**, con un enfoque comparativo. Cada explicación debe tener al menos 50 palabras, usando terminología técnica como “requerimientos estables”, “planificación predictiva”, “control de calidad estructurado”, etc.
#
# 2. **Explica y desarrolla otras 7 razones (distintas)** por las que NO se eligieron metodologías ágiles, también con enfoque técnico y explicaciones de más de 50 palabras. Usa conceptos como “equipos distribuidos”, “baja previsibilidad”, “poca documentación”, etc.
#
# 3. **Propón una solución combinada que use 4 modelos tradicionales** (como cascada, en V, incremental, prototipado). Justifica detalladamente cómo se complementan entre sí en este proyecto específico, con más de 100 palabras.
#
# 4. **Aplica terminología técnica adecuada** del área de calidad de software, arquitectura, pruebas, ciclo de vida del software, validación, mantenimiento, documentación, etc.
#
# 5. **Revisa redacción, estructura académica y ortografía**. El trabajo debe seguir este formato:
#    - Portada
#    - Introducción
#    - Desarrollo (razones tradicionales, razones no ágiles, modelos propuestos)
#    - Conclusión
#    - Bibliografía
#    - Anexos (opcional)
#
# 6. **Sugiere fuentes confiables y académicas** para complementar la investigación (máximo 30% del contenido puede provenir de internet). Incluir al menos una fuente académica (libro, paper, artículo indexado).
#
# ---
#
# ## 🗂 Archivos que tengo como referencia:
#
# - `M1- TI - Metodologías de Diseño de Software.pdf`
# - `Demostración M1 Metodologías de Diseño de Software.pdf`
# - Rúbrica de evaluación detallada (estructura formal, ortografía, citación, integración de modelos)
#
# ---
#
# ## 🛠️ Notas importantes
#
# - El informe está siendo estructurado también como notebook de Google Colab en `.ipynb`, por lo tanto puedo incorporar visualizaciones, DataFrames o tablas comparativas si aportan al análisis.
# - Puedes sugerirme visualizaciones útiles como: radar chart, heatmaps QA, análisis por categoría de calidad (pruebas, documentación, validación, gestión, etc.).
# - El lenguaje debe ser **técnico, claro, estructurado, y formal**, con estilo académico y enfoque en calidad de software y gestión de proyectos.
#
# ---
#
# 👉 ¿Puedes ayudarme a desarrollar, revisar o complementar este trabajo paso a paso, según los puntos anteriores?

# %% [markdown]
# ## 1. Introducción
#
# En el contexto actual de la transformación digital, la ingeniería del software se ha convertido en una disciplina estratégica para el desarrollo de soluciones tecnológicas eficientes, seguras y escalables. Las organizaciones con presencia global enfrentan desafíos crecientes en cuanto a la integración de sus operaciones, la gestión de grandes volúmenes de datos, la interoperabilidad de sistemas y la capacidad de responder a la demanda en tiempo real. EUROLOGISTIC, una empresa multinacional del rubro logístico, ha detectado una necesidad crítica: rediseñar su sistema de información central para soportar más de 50.000 transacciones por segundo, asegurando alta disponibilidad, trazabilidad de procesos y cumplimiento de normativas internacionales.
#
# Este escenario requiere no solo una solución tecnológica robusta, sino también un enfoque metodológico riguroso que permita controlar cada fase del desarrollo de software. En este sentido, la elección de una metodología no es trivial. Mientras que los enfoques ágiles priorizan la flexibilidad, iteración rápida y equipos autoorganizados, las metodologías tradicionales enfatizan la planificación anticipada, la documentación formal, la validación estructurada y el control jerárquico. Estas características resultan esenciales para EUROLOGISTIC, donde el sistema debe operar bajo requerimientos estables, plazos fijos, entornos regulados y equipos distribuidos geográficamente.
#
# En función de este contexto, el presente trabajo tiene como objetivo justificar la selección de metodologías tradicionales para el desarrollo del sistema de EUROLOGISTIC. Se analizan comparativamente las ventajas y limitaciones de las metodologías tradicionales frente a las ágiles, considerando criterios técnicos, organizacionales y de gestión de riesgos. Además, se propone una arquitectura metodológica combinada basada en modelos como Cascada, V, Incremental y Prototipos, que permiten abordar diferentes dimensiones del proyecto de forma escalonada y controlada.
#
# El documento utiliza terminología específica del área de desarrollo de software, y se apoya en fuentes académicas actualizadas y estándares internacionales como ISO/IEC 29119 e ISTQB. Su propósito es ofrecer una argumentación sólida y fundamentada, coherente con las buenas prácticas de aseguramiento de calidad y con los resultados de aprendizaje del módulo de Metodología de Diseño de Software.

# %%
# @title
import matplotlib.pyplot as plt

categories = ['Requerimientos', 'Coordinación', 'Calidad', 'Documentación', 'Planificación', 'Modularidad', 'Pruebas']
tradicional = [5, 5, 5, 5, 5, 5, 5]
agil = [2, 1, 2, 1, 2, 3, 3]

x = range(len(categories))

plt.figure(figsize=(10,6))
plt.barh(x, tradicional, color='steelblue', label='Tradicional')
plt.barh(x, [-a for a in agil], color='orange', label='Ágil')
plt.yticks(x, categories)
plt.xlabel("Grado de Adecuación (1-5)")
plt.title("Comparación Tradicional vs Ágil - Caso EUROLOGISTIC")
plt.legend()
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.show()

# %%
# @title
import pandas as pd

# Datos del Ítem 1
data = {
    "N°": [1, 2, 3, 4, 5, 6, 7],
    "Consideración": [
        "Planificación predictiva",
        "Requerimientos estables",
        "Gestión de riesgos estructurada",
        "Pruebas estructuradas y centralizadas",
        "Documentación formal",
        "Modelo secuencial y control jerárquico",
        "Alineación con entornos regulados"
    ],
    "Explicación": [
        "Las metodologías tradicionales, como el modelo en cascada, permiten una planificación completa desde las primeras etapas del ciclo de vida del software. Esta planificación predictiva asegura que los tiempos, recursos y entregables estén definidos antes de comenzar el desarrollo. Para EUROLOGISTIC, esta capacidad es esencial dado que el proyecto requiere precisión operativa, cumplimiento de plazos y asignación estratégica de recursos, algo que sería difícil de garantizar con metodologías iterativas y cambiantes como las ágiles.",

        "El proyecto de EUROLOGISTIC parte de requerimientos previamente definidos y validados por la dirección técnica y de negocios. Este contexto es ideal para metodologías tradicionales, las cuales funcionan mejor cuando los requerimientos son estables y no están sujetos a cambios constantes. A diferencia de las ágiles, que asumen cambios frecuentes, las tradicionales permiten construir un sistema robusto basado en especificaciones claras desde el inicio, reduciendo la incertidumbre y mejorando la calidad del producto final.",

        "Las metodologías tradicionales promueven una gestión de riesgos anticipada, ya que permiten identificar y documentar posibles contingencias desde las etapas iniciales. Esta capacidad es crucial en proyectos de alta complejidad técnica como el de EUROLOGISTIC, donde los errores pueden tener un impacto operativo global. Además, los modelos tradicionales incluyen planes de mitigación dentro de la planificación inicial, lo que disminuye la probabilidad de fallos críticos durante la implementación o despliegue del sistema.",

        "Una de las mayores fortalezas de los enfoques tradicionales es la existencia de fases formales de pruebas, como ocurre en el modelo en V, donde cada fase de desarrollo está asociada a una fase específica de validación. En un entorno como el de EUROLOGISTIC, donde el sistema debe gestionar más de 50.000 transacciones por segundo, es imprescindible contar con una estrategia de calidad rigurosa y estructurada que garantice la funcionalidad completa antes de la liberación.",

        "Las metodologías tradicionales exigen una documentación exhaustiva en cada etapa del proyecto, desde los requerimientos hasta las pruebas. Esto garantiza la trazabilidad, facilita el mantenimiento posterior del sistema y permite la incorporación de nuevos miembros al equipo sin pérdida de conocimiento. En empresas de gran escala como EUROLOGISTIC, esta documentación es crítica para asegurar continuidad operativa y cumplimiento de normativas internacionales o auditorías internas.",

        "El modelo secuencial facilita el control del flujo de trabajo, permitiendo que los líderes de proyecto puedan supervisar el avance fase por fase. En EUROLOGISTIC, donde intervienen múltiples áreas (logística, operaciones, TI, etc.), se requiere un modelo que permita ejercer un control jerárquico y coordinado de los equipos. Las metodologías ágiles, al ser más horizontales y autónomas, pueden dificultar esta supervisión formal.",

        "Muchas industrias con operaciones internacionales, como logística, transporte o finanzas, trabajan en entornos normativos exigentes. Las metodologías tradicionales se alinean mejor con estas exigencias, ya que incluyen procesos formales, auditorías y documentación verificable. En el caso de EUROLOGISTIC, esta alineación favorece el cumplimiento de estándares de calidad y seguridad que serían más difíciles de certificar bajo un enfoque ágil."
    ]
}

# Crear DataFrame
df_tradicional = pd.DataFrame(data)

# Guardar como Excel
excel_name = "Item1_Justificacion_Metodologias_Tradicionales.xlsx"
df_tradicional.to_excel(excel_name, index=False)

# Descargar el archivo en Colab
from google.colab import files
files.download(excel_name)

# %%
# @title
import pandas as pd

# Datos del Ítem 1
data = {
    "N°": [1, 2, 3, 4, 5, 6, 7],
    "Consideración": [
        "Planificación predictiva",
        "Requerimientos estables",
        "Gestión de riesgos estructurada",
        "Pruebas estructuradas y centralizadas",
        "Documentación formal",
        "Modelo secuencial y control jerárquico",
        "Alineación con entornos regulados"
    ],
    "Explicación": [
        "Las metodologías tradicionales, como el modelo en cascada, permiten una planificación completa desde las primeras etapas del ciclo de vida del software. Esta planificación predictiva asegura que los tiempos, recursos y entregables estén definidos antes de comenzar el desarrollo. Para EUROLOGISTIC, esta capacidad es esencial dado que el proyecto requiere precisión operativa, cumplimiento de plazos y asignación estratégica de recursos.",

        "El proyecto de EUROLOGISTIC parte de requerimientos previamente definidos y validados por la dirección técnica y de negocios. Este contexto es ideal para metodologías tradicionales, las cuales funcionan mejor cuando los requerimientos son estables y no están sujetos a cambios constantes. Las tradicionales permiten construir un sistema robusto basado en especificaciones claras desde el inicio, reduciendo la incertidumbre.",

        "Las metodologías tradicionales promueven una gestión de riesgos anticipada, ya que permiten identificar y documentar posibles contingencias desde las etapas iniciales. Esta capacidad es crucial en proyectos de alta complejidad técnica como el de EUROLOGISTIC, donde los errores pueden tener un impacto operativo global. Incluyen además planes de mitigación dentro de la planificación inicial.",

        "Una de las mayores fortalezas de los enfoques tradicionales es la existencia de fases formales de pruebas, como en el modelo en V, donde cada fase de desarrollo está asociada a una fase específica de validación. En EUROLOGISTIC, donde el sistema debe gestionar más de 50.000 transacciones por segundo, se necesita una estrategia de calidad rigurosa que asegure la funcionalidad completa antes de la liberación.",

        "Las metodologías tradicionales exigen una documentación exhaustiva en cada etapa del proyecto. Esto garantiza trazabilidad, facilita el mantenimiento posterior y permite la integración de nuevos miembros al equipo sin pérdida de conocimiento. En EUROLOGISTIC, la documentación es crítica para asegurar continuidad operativa y cumplimiento de normativas y auditorías internas.",

        "El modelo secuencial facilita el control del flujo de trabajo, permitiendo a los líderes de proyecto supervisar el avance fase por fase. En EUROLOGISTIC, donde intervienen múltiples áreas, se necesita un modelo que permita ejercer un control jerárquico y coordinado. Las metodologías ágiles, al ser horizontales, pueden dificultar esta supervisión formal en organizaciones grandes.",

        "Muchas industrias internacionales, como la logística, operan en contextos altamente regulados. Las metodologías tradicionales se ajustan mejor a estas exigencias debido a su enfoque en procesos formales, documentación verificable y cumplimiento de estándares. Para EUROLOGISTIC, esto facilita certificaciones, auditorías y la seguridad del sistema a gran escala."
    ]
}

# Crear el DataFrame y visualizarlo
df_item1 = pd.DataFrame(data)
df_item1  # Mostrar en Colab
# Out:
#    N°                           Consideración  \
# 0   1                Planificación predictiva
# 1   2                 Requerimientos estables
# 2   3         Gestión de riesgos estructurada
# 3   4   Pruebas estructuradas y centralizadas
# 4   5                    Documentación formal
# 5   6  Modelo secuencial y control jerárquico
# 6   7       Alineación con entornos regulados
#
#                                          Explicación
# 0  Las metodologías tradicionales, como el modelo...
# 1  El proyecto de EUROLOGISTIC parte de requerimi...
# 2  Las metodologías tradicionales promueven una g...
# 3  Una de las mayores fortalezas de los enfoques ...
# 4  Las metodologías tradicionales exigen una docu...
# 5  El modelo secuencial facilita el control del f...
# 6  Muchas industrias internacionales, como la log...

# %%
# @title
import pandas as pd
from IPython.display import display

# Datos completos con énfasis en la explicación
data = {
    "N°": [1, 2, 3, 4, 5, 6, 7],
    "Consideración": [
        "Planificación predictiva",
        "Requerimientos estables",
        "Gestión de riesgos estructurada",
        "Pruebas estructuradas y centralizadas",
        "Documentación formal",
        "Modelo secuencial y control jerárquico",
        "Alineación con entornos regulados"
    ],
    "Explicación": [
        "Las metodologías tradicionales, como el modelo en cascada, permiten una planificación completa desde las primeras etapas del ciclo de vida del software. Esta planificación predictiva asegura que los tiempos, recursos y entregables estén definidos antes de comenzar el desarrollo. Para EUROLOGISTIC, esta capacidad es esencial dado que el proyecto requiere precisión operativa, cumplimiento de plazos y asignación estratégica de recursos.",

        "El proyecto de EUROLOGISTIC parte de requerimientos previamente definidos y validados por la dirección técnica y de negocios. Este contexto es ideal para metodologías tradicionales, las cuales funcionan mejor cuando los requerimientos son estables y no están sujetos a cambios constantes. Las tradicionales permiten construir un sistema robusto basado en especificaciones claras desde el inicio, reduciendo la incertidumbre.",

        "Las metodologías tradicionales promueven una gestión de riesgos anticipada, ya que permiten identificar y documentar posibles contingencias desde las etapas iniciales. Esta capacidad es crucial en proyectos de alta complejidad técnica como el de EUROLOGISTIC, donde los errores pueden tener un impacto operativo global. Incluyen además planes de mitigación dentro de la planificación inicial.",

        "Una de las mayores fortalezas de los enfoques tradicionales es la existencia de fases formales de pruebas, como en el modelo en V, donde cada fase de desarrollo está asociada a una fase específica de validación. En EUROLOGISTIC, donde el sistema debe gestionar más de 50.000 transacciones por segundo, se necesita una estrategia de calidad rigurosa que asegure la funcionalidad completa antes de la liberación.",

        "Las metodologías tradicionales exigen una documentación exhaustiva en cada etapa del proyecto. Esto garantiza trazabilidad, facilita el mantenimiento posterior y permite la integración de nuevos miembros al equipo sin pérdida de conocimiento. En EUROLOGISTIC, la documentación es crítica para asegurar continuidad operativa y cumplimiento de normativas y auditorías internas.",

        "El modelo secuencial facilita el control del flujo de trabajo, permitiendo a los líderes de proyecto supervisar el avance fase por fase. En EUROLOGISTIC, donde intervienen múltiples áreas, se necesita un modelo que permita ejercer un control jerárquico y coordinado. Las metodologías ágiles, al ser horizontales, pueden dificultar esta supervisión formal en organizaciones grandes.",

        "Muchas industrias internacionales, como la logística, operan en contextos altamente regulados. Las metodologías tradicionales se ajustan mejor a estas exigencias debido a su enfoque en procesos formales, documentación verificable y cumplimiento de estándares. Para EUROLOGISTIC, esto facilita certificaciones, auditorías y la seguridad del sistema a gran escala."
    ]
}

# Crear DataFrame
df_item1 = pd.DataFrame(data)

# Estilizar para mejor visualización
styled_df = df_item1.style.hide(axis="index")\
    .set_table_attributes("style='width:100%; font-size:15px; border-collapse:collapse;'")\
    .set_properties(subset=["N°"], **{'width': '30px', 'text-align': 'center'})\
    .set_properties(subset=["Consideración"], **{'width': '220px', 'font-weight': 'bold', 'text-align': 'left'})\
    .set_properties(subset=["Explicación"], **{
        'width': '700px',
        'text-align': 'justify',
        'line-height': '1.5',
        'padding': '8px'
    })

# Mostrar la tabla con estilo
display(styled_df)
# Out:
# <style type="text/css">
# #T_45541_row0_col0, #T_45541_row1_col0, #T_45541_row2_col0, #T_45541_row3_col0, #T_45541_row4_col0, #T_45541_row5_col0, #T_45541_row6_col0 {
#   width: 30px;
#   text-align: center;
# }
# #T_45541_row0_col1, #T_45541_row1_col1, #T_45541_row2_col1, #T_45541_row3_col1, #T_45541_row4_col1, #T_45541_row5_col1, #T_45541_row6_col1 {
#   width: 220px;
#   font-weight: bold;
#   text-align: left;
# }
# #T_45541_row0_col2, #T_45541_row1_col2, #T_45541_row2_col2, #T_45541_row3_col2, #T_45541_row4_col2, #T_45541_row5_col2, #T_45541_row6_col2 {
#   width: 700px;
#   text-align: justify;
#   line-height: 1.5;
#   padding: 8px;
# }
# </style>
# <table id="T_45541" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_45541_level0_col0" class="col_heading level0 col0" >N°</th>
#       <th id="T_45541_level0_col1" class="col_heading level0 col1" >Consideración</th>
#       <th id="T_45541_level0_col2" class="col_heading level0 col2" >Explicación</th>
#     </tr>
# ...

# %%
# @title
import matplotlib.pyplot as plt

categories = ['Requerimientos', 'Coordinación', 'Calidad', 'Documentación', 'Planificación', 'Modularidad', 'Pruebas']
tradicional = [5, 5, 5, 5, 5, 5, 5]
agil = [2, 1, 2, 1, 2, 3, 3]

x = range(len(categories))

plt.figure(figsize=(10,6))
plt.barh(x, tradicional, color='steelblue', label='Tradicional')
plt.barh(x, [-a for a in agil], color='orange', label='Ágil')
plt.yticks(x, categories)
plt.xlabel("Grado de Adecuación (1-5)")
plt.title("Comparación Tradicional vs Ágil - Caso EUROLOGISTIC")
plt.legend()
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Ítem 2: Justificación de la No Selección de Metodologías Ágiles
#
# La siguiente tabla presenta siete consideraciones técnicas por las cuales se descartó el uso de metodologías ágiles en el caso de EUROLOGISTIC. Se argumentan factores como la dificultad de integración en equipos distribuidos, baja previsibilidad en costos y tiempos, y ausencia de control jerárquico. Estas condiciones no se alinean con las necesidades de una empresa global que requiere estabilidad, trazabilidad y cumplimiento de estándares.
#
# Cada punto está desarrollado con enfoque técnico y evidencia el riesgo que representa aplicar metodologías ágiles en un proyecto de esta naturaleza.

# %%
# @title
import pandas as pd
from IPython.display import display

# Datos del ítem 2
data = {
    "N°": [1, 2, 3, 4, 5, 6, 7],
    "Consideración": [
        "Dificultad para integrar equipos distribuidos",
        "Baja previsibilidad de plazos y costos",
        "Mínima documentación técnica",
        "Dificultad en la creación de historias de usuario",
        "Inadecuado para requisitos fijos",
        "Riesgo en entregas parciales",
        "Falta de control jerárquico"
    ],
    "Explicación": [
        "EUROLOGISTIC opera en múltiples continentes, lo que dificulta la coordinación constante que exigen las metodologías ágiles. Estas dependen de una comunicación frecuente y sincrónica, como daily meetings y sesiones de planificación, que son difíciles de implementar en equipos distribuidos. Esto compromete la eficiencia y sincronización del desarrollo.",

        "Las metodologías ágiles permiten cambios constantes en el alcance, lo cual dificulta la planificación precisa de tiempo y costos. EUROLOGISTIC, al ser una empresa con estructura corporativa internacional, necesita asegurar presupuestos, recursos y cronogramas definidos. Esta falta de previsibilidad representa un riesgo estratégico.",

        "El enfoque ágil minimiza la generación de documentación técnica en favor del desarrollo continuo. Sin embargo, EUROLOGISTIC requiere registros completos para auditorías, mantenimiento global y soporte a largo plazo. La ausencia de esta documentación puede limitar la escalabilidad y gestión del sistema en el futuro.",

        "Las metodologías ágiles requieren traducir necesidades a historias de usuario. En proyectos con lógica empresarial compleja como este, donde los requerimientos son técnicos y formales, esta traducción puede generar ambigüedad, errores de interpretación y soluciones incompletas.",

        "EUROLOGISTIC ya definió claramente sus requerimientos. Aplicar un enfoque ágil, diseñado para iterar y adaptarse a cambios, resultaría innecesario y costoso. El uso de metodologías tradicionales permite implementar con mayor eficiencia lo que ya está especificado sin introducir incertidumbre adicional.",

        "La entrega incremental de funcionalidades en Ágil puede ser problemática en sistemas que requieren una arquitectura completa para ser útiles. En el caso de EUROLOGISTIC, la entrega de módulos aislados o incompletos compromete la validación e integración general del sistema.",

        "En metodologías ágiles, los equipos suelen ser autónomos y autoorganizados. Esto limita el control jerárquico desde la dirección, que es fundamental en EUROLOGISTIC para alinear decisiones técnicas con estrategias corporativas globales. La falta de supervisión formal podría causar desviaciones importantes."
    ]
}

# Crear DataFrame
df_item2 = pd.DataFrame(data)

# Estilizado claro y sin índice
styled_df = df_item2.style.hide(axis="index")\
    .set_table_attributes("style='width:100%; font-size:14px;'")\
    .set_properties(subset=["N°"], **{'width': '30px', 'text-align': 'center'})\
    .set_properties(subset=["Consideración"], **{'width': '240px', 'font-weight': 'bold'})\
    .set_properties(subset=["Explicación"], **{
        'width': '700px',
        'text-align': 'justify',
        'line-height': '1.5',
        'padding': '8px'
    })

# Mostrar en Colab
display(styled_df)
# Out:
# <style type="text/css">
# #T_1f268_row0_col0, #T_1f268_row1_col0, #T_1f268_row2_col0, #T_1f268_row3_col0, #T_1f268_row4_col0, #T_1f268_row5_col0, #T_1f268_row6_col0 {
#   width: 30px;
#   text-align: center;
# }
# #T_1f268_row0_col1, #T_1f268_row1_col1, #T_1f268_row2_col1, #T_1f268_row3_col1, #T_1f268_row4_col1, #T_1f268_row5_col1, #T_1f268_row6_col1 {
#   width: 240px;
#   font-weight: bold;
# }
# #T_1f268_row0_col2, #T_1f268_row1_col2, #T_1f268_row2_col2, #T_1f268_row3_col2, #T_1f268_row4_col2, #T_1f268_row5_col2, #T_1f268_row6_col2 {
#   width: 700px;
#   text-align: justify;
#   line-height: 1.5;
#   padding: 8px;
# }
# </style>
# <table id="T_1f268" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_1f268_level0_col0" class="col_heading level0 col0" >N°</th>
#       <th id="T_1f268_level0_col1" class="col_heading level0 col1" >Consideración</th>
#       <th id="T_1f268_level0_col2" class="col_heading level0 col2" >Explicación</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
# @title
import matplotlib.pyplot as plt

# Datos: 7 consideraciones del ítem 2
factores = [
    "Baja documentación técnica",
    "Dificultad para equipos distribuidos",
    "Falta de control jerárquico",
    "Riesgo en entregas parciales",
    "Baja previsibilidad de costos y tiempos",
    "Inadecuado para requisitos fijos",
    "Dificultad en historias de usuario"
]

# Grado de impacto negativo (1 = bajo, 5 = crítico)
impacto = [5, 5, 4, 5, 5, 4, 4]

# Colores personalizados para cada barra
colores = [
    "#FF6F61",  # rojo coral
    "#6B5B95",  # morado oscuro
    "#88B04B",  # verde
    "#FFA500",  # naranja
    "#00BFFF",  # azul celeste
    "#D65076",  # rosa fuerte
    "#45B8AC"   # verde azulado
]

# Crear gráfico
plt.figure(figsize=(12, 6))
bars = plt.barh(factores, impacto, color=colores)

# Etiquetas y título
plt.xlabel("Grado de Impacto Negativo (1 = Bajo, 5 = Crítico)")
plt.title("Factores que Justifican No Usar Metodologías Ágiles - Caso EUROLOGISTIC")
plt.gca().invert_yaxis()  # Mostrar el más crítico arriba

# Añadir valores sobre las barras
for bar in bars:
    plt.text(bar.get_width() + 0.1, bar.get_y() + 0.3, f'{bar.get_width()}', va='center')

plt.tight_layout()
plt.show()

# %%
# @title
import matplotlib.pyplot as plt
import numpy as np

# Criterios de evaluación
categorias = [
    "Requerimientos Estables",
    "Coordinación Global",
    "Supervisión Jerárquica",
    "Documentación Formal",
    "Planificación",
    "Validación de Calidad",
    "Modularidad de Entregas"
]

# Desempeño (1 a 5)
tradicional = [5, 5, 5, 5, 5, 5, 4]
agil =        [2, 2, 2, 1, 2, 3, 4]

# Número de variables
N = len(categorias)

# Ángulos
ángulos = np.linspace(0, 2 * np.pi, N, endpoint=False).tolist()
ángulos += [ángulos[0]]  # cerrar el gráfico

# Cerrar los datos para formar el lazo
tradicional += [tradicional[0]]
agil += [agil[0]]

# Crear el gráfico
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# Dibujar líneas
ax.plot(ángulos, tradicional, label='Tradicional', color='green', linewidth=2)
ax.fill(ángulos, tradicional, color='green', alpha=0.25)

ax.plot(ángulos, agil, label='Ágil', color='orange', linewidth=2, linestyle='dashed')
ax.fill(ángulos, agil, color='orange', alpha=0.2)

# Añadir etiquetas (sin repetir la primera categoría)
ax.set_xticks(ángulos[:-1])
ax.set_xticklabels(categorias, fontsize=11)

# Escala radial
ax.set_yticks([1, 2, 3, 4, 5])
ax.set_yticklabels(['1','2','3','4','5'])

# Título y leyenda
ax.set_title("Comparación de Metodologías: Tradicional vs Ágil - EUROLOGISTIC", size=14, pad=20)
ax.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))

plt.tight_layout()
plt.show()

# %%
# @title
import matplotlib.pyplot as plt

# Factores por los que NO se eligió Ágil
factores = [
    "Dificultad para equipos distribuidos",
    "Baja previsibilidad en tiempo y costo",
    "Falta de documentación técnica formal",
    "Entregas parciales arriesgadas",
    "Inadecuado para requisitos fijos",
    "Falta de control jerárquico",
    "Historias de usuario poco aplicables"
]

# Escala de impacto negativo (1 = bajo, 5 = crítico)
impacto = [5, 5, 4, 5, 4, 4, 3]

# Colores personalizados para destacar
colores = [
    "#FF5733", "#FF8D1A", "#FFC300",
    "#DAF7A6", "#75FF33", "#33FFF6", "#3380FF"
]

# Crear la figura
plt.figure(figsize=(12, 7))
bars = plt.barh(factores, impacto, color=colores)

# Añadir etiquetas a cada barra
for bar in bars:
    plt.text(bar.get_width() + 0.1, bar.get_y() + 0.3, f'{bar.get_width()}', va='center', fontsize=10)

# Ajustes estéticos
plt.xlabel("Grado de Incompatibilidad (1 = Bajo, 5 = Crítico)", fontsize=12)
plt.title("Factores que Justifican No Usar Metodologías Ágiles - EUROLOGISTIC", fontsize=14, pad=15)
plt.gca().invert_yaxis()  # Mostrar de arriba a abajo

plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# @title
import matplotlib.pyplot as plt

# Factores que limitan Ágil
factores = [
    "Dificultad equipos distribuidos",
    "Baja previsibilidad",
    "Falta documentación técnica",
    "Entregas parciales arriesgadas",
    "Requisitos fijos",
    "Falta control jerárquico",
    "Historias de usuario complejas"
]

# Se asignan valores proporcionalmente (puedes ajustarlos)
impacto = [20, 20, 15, 15, 10, 10, 10]

# Colores agradables y distintos
colores = ['#FF6F61', '#6B5B95', '#88B04B', '#F7CAC9', '#92A8D1', '#955251', '#B565A7']

# Crear el gráfico
plt.figure(figsize=(8, 8))
plt.pie(impacto, labels=factores, colors=colores, autopct='%1.1f%%', startangle=140, textprops={'fontsize': 10})
plt.title("Distribución de Factores Críticos que Limitan el Uso de Metodologías Ágiles", fontsize=13)
plt.axis('equal')  # Hacer el círculo perfecto
plt.tight_layout()
plt.show()

# %%
# @title
import matplotlib.pyplot as plt
import numpy as np

# Datos
factores = [
    "Coordinación Global",
    "Previsibilidad",
    "Documentación",
    "Entregas Integradas",
    "Requisitos Estables",
    "Supervisión Directiva",
    "Historias Técnicas Claras"
]

tradicional = [5, 5, 5, 5, 5, 5, 4]
agil =        [2, 2, 1, 2, 2, 2, 3]

x = np.arange(len(factores))
width = 0.35

# Colores únicos por barra
colores_trad = ['#2E8B57', '#66CDAA', '#3CB371', '#20B2AA', '#5F9EA0', '#228B22', '#008B8B']
colores_agil = ['#FF6347', '#FFA07A', '#FF8C00', '#F4A460', '#DAA520', '#CD5C5C', '#D2691E']

# Crear figura
fig, ax = plt.subplots(figsize=(13, 6))

# Dibujar barras con colores únicos
for i in range(len(x)):
    ax.bar(x[i] - width/2, tradicional[i], width, color=colores_trad[i], label='Tradicional' if i == 0 else "")
    ax.bar(x[i] + width/2, agil[i], width, color=colores_agil[i], label='Ágil' if i == 0 else "")

# Etiquetas
ax.set_ylabel("Nivel de Compatibilidad (1 = Bajo, 5 = Alto)", fontsize=12)
ax.set_xlabel("Grado de Incompatibilidad (1 = Bajo, 5 = Crítico)", fontsize=12)
ax.set_title("Comparación Tradicional vs Ágil según criterios técnicos - EUROLOGISTIC", fontsize=14, pad=15)
ax.set_xticks(x)
ax.set_xticklabels(factores, rotation=30, ha='right')
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.4)

plt.tight_layout()

# Guardar como archivo .jpg
plt.savefig("comparacion_tradicional_vs_agil.jpg", format='jpg', dpi=300)

# Mostrar en pantalla
plt.show()

# %%
# @title
from google.colab import files
files.download("comparacion_tradicional_vs_agil.jpg")

# %% [markdown]
# ## Ítem 3: Propuesta de Modelos Tradicionales Combinados
#
# Para abordar la complejidad y escala del sistema de información de EUROLOGISTIC, se propone una estrategia híbrida basada en cuatro modelos tradicionales: cascada, en V, incremental y prototipos. Esta combinación permite aprovechar la planificación rigurosa y la validación formal que exige el proyecto, al tiempo que ofrece flexibilidad parcial para componentes en fase exploratoria.
#
# A continuación se detalla la justificación técnica de cada modelo.

# %%
# @title
import pandas as pd
from IPython.display import display

# Datos del Ítem 3
data = {
    "N°": [1, 2, 3, 4],
    "Modelo": [
        "Modelo en Cascada",
        "Modelo en V",
        "Modelo Incremental",
        "Modelo de Prototipos"
    ],
    "Justificación Técnica": [
        "Este modelo proporciona una estructura secuencial y altamente planificada, ideal para proyectos con requerimientos estables como el de EUROLOGISTIC. Permite una clara delimitación de etapas (análisis, diseño, codificación, pruebas, implementación) y facilita el control documental y de calidad en cada fase. Es especialmente útil para garantizar trazabilidad en un entorno corporativo regulado.",

        "Refuerza la estrategia de pruebas al vincular directamente cada fase de desarrollo con su respectiva validación. Esto garantiza que los requerimientos críticos sean verificados desde el inicio. Para EUROLOGISTIC, que gestiona más de 50,000 transacciones por segundo, este modelo proporciona un marco robusto para validar rendimiento, escalabilidad y cumplimiento de normas desde las etapas tempranas.",

        "Permite construir el sistema en bloques funcionales, priorizando los módulos más críticos. En un sistema global como este, esta estrategia minimiza el riesgo al permitir pruebas y despliegues por fases. También facilita el control de calidad continuo y permite incorporar retroalimentación técnica sin comprometer la arquitectura global del sistema.",

        "Útil para explorar áreas aún no bien definidas, como los módulos de inteligencia de negocio o analítica avanzada. Este modelo permite presentar versiones tempranas a los usuarios internos, recoger su retroalimentación y refinar funcionalidades antes de integrarlas al desarrollo formal. Reduce la incertidumbre y mejora la alineación con los objetivos de negocio antes del desarrollo definitivo."
    ]
}

# Crear el DataFrame
df_item3 = pd.DataFrame(data)

# Estilizado visual
styled_df = df_item3.style.hide(axis="index")\
    .set_table_attributes("style='width:100%; font-size:14px'")\
    .set_properties(subset=["N°"], **{'width': '30px', 'text-align': 'center'})\
    .set_properties(subset=["Modelo"], **{'width': '200px', 'font-weight': 'bold'})\
    .set_properties(subset=["Justificación Técnica"], **{
        'width': '700px',
        'text-align': 'justify',
        'line-height': '1.6',
        'padding': '8px'
    })

# Mostrar en Colab
display(styled_df)
# Out:
# <style type="text/css">
# #T_5b33c_row0_col0, #T_5b33c_row1_col0, #T_5b33c_row2_col0, #T_5b33c_row3_col0 {
#   width: 30px;
#   text-align: center;
# }
# #T_5b33c_row0_col1, #T_5b33c_row1_col1, #T_5b33c_row2_col1, #T_5b33c_row3_col1 {
#   width: 200px;
#   font-weight: bold;
# }
# #T_5b33c_row0_col2, #T_5b33c_row1_col2, #T_5b33c_row2_col2, #T_5b33c_row3_col2 {
#   width: 700px;
#   text-align: justify;
#   line-height: 1.6;
#   padding: 8px;
# }
# </style>
# <table id="T_5b33c" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_5b33c_level0_col0" class="col_heading level0 col0" >N°</th>
#       <th id="T_5b33c_level0_col1" class="col_heading level0 col1" >Modelo</th>
#       <th id="T_5b33c_level0_col2" class="col_heading level0 col2" >Justificación Técnica</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5b33c_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_5b33c_row0_col1" class="data row0 col1" >Modelo en Cascada</td>
# ...

# %%
# @title
import plotly.graph_objects as go
import pandas as pd

# Datos del ítem 3 (resumen)
data = {
    "Modelo": [
        "Modelo en Cascada",
        "Modelo en V",
        "Modelo Incremental",
        "Modelo de Prototipos"
    ],
    "Justificación Técnica": [
        "Estructura secuencial ideal para proyectos con requerimientos estables. Facilita trazabilidad y control documental en entornos regulados.",
        "Integra validación en cada fase. Es clave para proyectos de alta criticidad como EUROLOGISTIC donde la validación temprana reduce riesgos técnicos.",
        "Permite entregar el sistema por módulos funcionales. Favorece la retroalimentación, pruebas tempranas y control de riesgos.",
        "Ideal para explorar módulos en fase experimental. Permite refinar funcionalidades con usuarios antes de su implementación formal."
    ]
}

df_plotly = pd.DataFrame(data)

# Crear tabla con Plotly
fig = go.Figure(data=[go.Table(
    columnwidth=[50, 250],
    header=dict(
        values=["<b>Modelo</b>", "<b>Justificación Técnica</b>"],
        fill_color='#003366',
        font=dict(color='white', size=12),
        align='left'
    ),
    cells=dict(
        values=[df_plotly[col] for col in df_plotly.columns],
        fill_color='#F2F2F2',
        align='left',
        font=dict(size=11),
        height=40
    )
)])

fig.update_layout(width=1000, height=400, title_text="Modelos Tradicionales Propuestos - Proyecto EUROLOGISTIC")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# @title
import plotly.express as px

# Datos para línea de tiempo
timeline_data = pd.DataFrame({
    "Modelo": ["Cascada", "V", "Incremental", "Prototipos"],
    "Inicio": ["2024-05-01", "2024-05-10", "2024-06-01", "2024-06-10"],
    "Fin": ["2024-06-10", "2024-06-20", "2024-07-20", "2024-07-10"],
    "Fase": [
        "Planificación global",
        "Validación técnica",
        "Desarrollo modular",
        "Exploración y ajustes"
    ]
})

fig = px.timeline(
    timeline_data,
    x_start="Inicio",
    x_end="Fin",
    y="Modelo",
    color="Modelo",
    text="Fase"
)

fig.update_layout(
    title="Integración de Modelos Tradicionales - Cronograma de Aplicación",
    xaxis_title="Fecha",
    yaxis_title="Modelo",
    showlegend=False,
    width=950,
    height=400
)
fig.update_traces(marker=dict(line_color='black'), textposition='inside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# @title
import plotly.graph_objects as go
import pandas as pd
from plotly.subplots import make_subplots

# Datos del modelo
data = {
    'Fase': [
        "1. Requisitos", "2. Análisis", "3. Diseño", "4. Implementación",
        "5. Pruebas", "6. Despliegue", "7. Mantenimiento"
    ],
    'Descripción': [
        "Validación técnica de requerimientos estables",
        "Análisis técnico de procesos y datos",
        "Diseño arquitectónico del sistema",
        "Codificación (50k+ transacciones/seg)",
        "Pruebas funcionales y de carga integradas",
        "Despliegue global con monitoreo",
        "Soporte continuo y mejoras escalables"
    ],
    'Duración': [4, 3, 5, 8, 6, 3, 12],
}

df = pd.DataFrame(data)
df = df[::-1].reset_index(drop=True)  # Invertir para cascada descendente

# Paleta de colores corporativos (variaciones de azul)
colores_azulados = ['#003366', '#004080', '#0059B3', '#0066CC', '#0073E6', '#0080FF', '#1E90FF']

# Crear figura con subplots
fig = make_subplots(
    rows=2, cols=1,
    specs=[[{"type": "bar"}], [{"type": "table"}]],
    row_heights=[0.7, 0.3],
    vertical_spacing=0.05
)

# Crear bloques tipo cascada descendente (de derecha a izquierda) con colores diferenciados
for i, row in df.iterrows():
    fig.add_trace(go.Bar(
        y=[row['Fase']],
        x=[-2.5],                      # Largo horizontal del bloque
        orientation='h',
        width=0.9,                      # Alto del bloque (casi cuadrado)
        base=-(1 + i * 0.45),          # Separación horizontal para efecto cascada
        marker=dict(color=colores_azulados[i]), # 🎨 COLOR DIFERENCIADO
        text=f"<b>{row['Fase']}</b><br><br>{row['Descripción']}<br><br><i>Duración: {row['Duración']} semanas</i>",
        textposition="inside",
        textfont=dict(size=20, color='white'),  # 🔠 LETRA MÁS GRANDE
        insidetextanchor='middle',
        hoverinfo='none'
    ), row=1, col=1)

# Agregar tabla resumen
tabla_df = pd.DataFrame(data)

fig.add_trace(go.Table(
    header=dict(
        values=["<b>Fase</b>", "<b>Descripción</b>", "<b>Duración (semanas)</b>"],
        fill_color=colores_azulados[0], # Usar el primer color para el encabezado
        font=dict(color='white', size=16),
        align='left'
    ),
    cells=dict(
        values=[tabla_df.Fase, tabla_df.Descripción, tabla_df.Duración],
        fill_color=['white', '#f2f2f2', 'white'],
        font=dict(size=13),
        align='left'
    )
), row=2, col=1)

# Layout final más compacto
fig.update_layout(
    title=dict(
        text="<b>EUROLOGISTIC - Modelo en Cascada (Horizontal, derecha a izquierda)</b>",
        x=0.5,
        y=0.95,
        font=dict(size=22)
    ),
    height=750,  # Más compacto
    width=1250,
    margin=dict(l=20, r=20, t=60, b=30),
    plot_bgcolor='white',
    paper_bgcolor='white',
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# @title
import plotly.graph_objects as go
import pandas as pd
from plotly.subplots import make_subplots

# Datos del modelo
data = {
    'Fase': [
        "1. Requisitos", "2. Análisis", "3. Diseño", "4. Implementación",
        "5. Pruebas", "6. Despliegue", "7. Mantenimiento"
    ],
    'Descripción': [
        "Validación técnica de requerimientos estables",
        "Análisis técnico de procesos y datos",
        "Diseño arquitectónico del sistema",
        "Codificación (50k+ transacciones/seg)",
        "Pruebas funcionales y de carga integradas",
        "Despliegue global con monitoreo",
        "Soporte continuo y mejoras escalables"
    ],
    'Duración': [4, 3, 5, 8, 6, 3, 12],
}
df = pd.DataFrame(data)
df = df[::-1].reset_index(drop=True)  # Invertir para cascada descendente

# Nueva paleta de colores corporativos más vibrantes para destacar sobre negro
colores_corporativos = ['#00A8E8', '#007EA7', '#1B98E0', '#4CB5F5', '#0077B6', '#59C1FF', '#81D4FA']

# Crear figura con subplots
fig = make_subplots(
    rows=2, cols=1,
    specs=[[{"type": "bar"}], [{"type": "table"}]],
    row_heights=[0.7, 0.3],
    vertical_spacing=0.05
)

# Crear bloques tipo cascada descendente (de derecha a izquierda) con colores diferenciados
for i, row in df.iterrows():
    fig.add_trace(go.Bar(
        y=[row['Fase']],
        x=[-2.5],                      # Largo horizontal del bloque
        orientation='h',
        width=0.9,                      # Alto del bloque (casi cuadrado)
        base=-(1 + i * 0.45),          # Separación horizontal para efecto cascada
        marker=dict(color=colores_corporativos[i], line=dict(width=1, color='#FFFFFF')),
        text=f"<b>{row['Fase']}</b><br><br>{row['Descripción']}<br><br><i>Duración: {row['Duración']} semanas</i>",
        textposition="inside",
        textfont=dict(size=20, color='white'),
        insidetextanchor='middle',
        hoverinfo='none'
    ), row=1, col=1)

# Agregar tabla resumen con colores adaptados al fondo negro
tabla_df = pd.DataFrame(data)
fig.add_trace(go.Table(
    header=dict(
        values=["<b>Fase</b>", "<b>Descripción</b>", "<b>Duración (semanas)</b>"],
        fill_color='#004080',
        font=dict(color='white', size=16),
        align='left'
    ),
    cells=dict(
        values=[tabla_df.Fase, tabla_df.Descripción, tabla_df.Duración],
        fill_color=['rgba(70, 70, 70, 0.7)', 'rgba(50, 50, 50, 0.7)', 'rgba(70, 70, 70, 0.7)'],
        font=dict(color='white', size=13),
        align='left'
    )
), row=2, col=1)

# Layout final con fondo negro corporativo
fig.update_layout(
    title=dict(
        text="<b>EUROLOGISTIC - Modelo en Cascada (Horizontal)</b>",
        x=0.5,
        y=0.95,
        font=dict(size=24, color='white')
    ),
    height=750,
    width=1250,
    margin=dict(l=20, r=20, t=60, b=30),
    plot_bgcolor='black',
    paper_bgcolor='black',
    showlegend=False,
    # Actualización de los ejes para que resalten sobre el fondo negro
    yaxis=dict(
        showgrid=False,
        showticklabels=False,
        zeroline=False
    ),
    xaxis=dict(
        showgrid=False,
        showticklabels=False,
        zeroline=False
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# @title
import plotly.graph_objects as go
import pandas as pd
from plotly.subplots import make_subplots

# Datos del modelo EUROLOGISTIC
data = {
    'Fase': [
        "1. Requisitos", "2. Análisis", "3. Diseño", "4. Implementación",
        "5. Pruebas", "6. Despliegue", "7. Mantenimiento"
    ],
    'Descripción': [
        "Validación técnica\nde requerimientos estables",
        "Análisis técnico\nde procesos y datos",
        "Diseño arquitectónico\ndel sistema",
        "Codificación con soporte de\n50,000+ transacciones por segundo",
        "Pruebas funcionales y de carga\nintegradas y estructuradas",
        "Despliegue global con\nmonitoreo constante",
        "Soporte continuo y\nmejoras escalables"
    ],
    'Duración': [4, 3, 5, 8, 6, 3, 12],
}

df = pd.DataFrame(data)
df = df[::-1].reset_index(drop=True)

# Paleta azul corporativa
colores_azulados = ['#003366', '#004080', '#0059B3', '#0066CC', '#0073E6', '#0080FF', '#1E90FF']

# Crear figura
fig = make_subplots(
    rows=2, cols=1,
    specs=[[{"type": "bar"}], [{"type": "table"}]],
    row_heights=[0.7, 0.3],
    vertical_spacing=0.05
)

# Agregar bloques con mejor legibilidad
for i, row in df.iterrows():
    texto_legible = f"<b>{row['Fase']}</b>\n\n{row['Descripción']}\n\n<i>Duración: {row['Duración']} semanas</i>"
    fig.add_trace(go.Bar(
        y=[row['Fase']],
        x=[-3],                      # Más ancho horizontal
        orientation='h',
        width=0.95,                  # Alto del bloque
        base=-(1 + i * 0.48),
        marker=dict(color=colores_azulados[i]),
        text=texto_legible,
        textposition="inside",
        textfont=dict(size=24, color='white'),  # 🔠 Letra más grande para imagen
        insidetextanchor='middle',
        hoverinfo='none'
    ), row=1, col=1)

# Tabla informativa
fig.add_trace(go.Table(
    header=dict(
        values=["<b>Fase</b>", "<b>Descripción</b>", "<b>Duración (semanas)</b>"],
        fill_color=colores_azulados[0],
        font=dict(color='white', size=16),
        align='left'
    ),
    cells=dict(
        values=[df[::-1].Fase, df[::-1].Descripción, df[::-1].Duración],
        fill_color=['white', '#f2f2f2', 'white'],
        font=dict(size=13),
        align='left'
    )
), row=2, col=1)

# Layout general optimizado
fig.update_layout(
    title=dict(
        text="<b>EUROLOGISTIC - Modelo en Cascada</b><br><span style='font-size:14px; color:gray'>Visualización horizontal para inserción en Word</span>",
        x=0.5,
        y=0.95,
        font=dict(size=22)
    ),
    height=850,   # Más altura para exportación clara
    width=1400,   # Más ancho para caber bien en Word horizontal
    margin=dict(l=20, r=20, t=70, b=30),
    plot_bgcolor='white',
    paper_bgcolor='white',
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# @title
from dataclasses import dataclass
from typing import List, Tuple, Dict, Optional
import plotly.graph_objects as go

@dataclass
class VPhase:
    """Clase que representa una fase del modelo en V con estilo profesional."""
    name: str
    description: str
    color: str
    coordinates: Tuple[float, float]
    width: float = 2.4            # Ancho ampliado para mayor legibilidad
    height: float = 1.6           # Alto ampliado para mayor legibilidad
    text_color: str = 'white'     # Color de texto predeterminado
    title_font_size: int = 22     # Tamaño de fuente para el título
    desc_font_size: int = 16      # Tamaño de fuente para la descripción
    hover_text: str = None        # Texto adicional para el hover (opcional)

class EnhancedVModelDiagram:
    """Generador de diagramas de Modelo en V con diseño profesional y alta legibilidad."""

    def __init__(
        self,
        title: str = "MODELO EN V",
        subtitle: str = "Desarrollo y Validación de Software",
        company: str = "EUROLOGISTIC",
        copyright_text: str = "© EUROLOGISTIC - Metodología de Desarrollo de Software",
        theme: str = "corporate"   # Opciones: 'corporate', 'modern', 'classic'
    ):
        """
        Inicializa el generador del diagrama del Modelo en V.

        Args:
            title: Título principal del diagrama
            subtitle: Subtítulo descriptivo
            company: Nombre de la empresa para mostrar en el título
            copyright_text: Texto de copyright a mostrar
            theme: Tema de colores ('corporate', 'modern', 'classic')
        """
        self.title = title
        self.subtitle = subtitle
        self.company = company
        self.copyright_text = copyright_text
        self.theme = theme

        # Inicializar figura
        self.fig = go.Figure()

        # Configurar tema y colores
        self._set_theme(theme)

        # Crear fases del modelo
        self.left_phases = self._create_development_phases()
        self.central_phase = self._create_implementation_phase()
        self.right_phases = self._create_validation_phases()

        # Configurar layout base
        self._configure_layout()

    def _set_theme(self, theme: str):
        """Configura las paletas de colores y estilos según el tema seleccionado."""
        themes = {
            'corporate': {
                'primary': '#003366',
                'secondary': '#004D99',
                'accent': '#FF8C00',
                'development': ['#0A3D7E', '#1C5CAA', '#2F7BD6'],
                'validation': ['#2F7BD6', '#1C5CAA', '#0A3D7E'],
                'line': '#AAAAAA',
                'connection_line': '#DDDDDD',
                'bg': 'white',
                'title_color': '#003366',
                'text_color': 'white',
                'desc_color_outside': '#333333',
                'font_family': 'Arial, sans-serif'
            },
            'modern': {
                'primary': '#2C3E50',
                'secondary': '#34495E',
                'accent': '#E74C3C',
                'development': ['#2C3E50', '#34495E', '#3A536B'],
                'validation': ['#3A536B', '#34495E', '#2C3E50'],
                'line': '#95A5A6',
                'connection_line': '#BDC3C7',
                'bg': 'white',
                'title_color': '#2C3E50',
                'text_color': 'white',
                'desc_color_outside': '#34495E',
                'font_family': 'Helvetica, Arial, sans-serif'
            },
            'classic': {
                'primary': '#1B4F72',
                'secondary': '#21618C',
                'accent': '#D35400',
                'development': ['#1B4F72', '#2874A6', '#3498DB'],
                'validation': ['#3498DB', '#2874A6', '#1B4F72'],
                'line': '#85929E',
                'connection_line': '#D5D8DC',
                'bg': 'white',
                'title_color': '#1B4F72',
                'text_color': 'white',
                'desc_color_outside': '#273746',
                'font_family': 'Times New Roman, serif'
            }
        }

        # Aplicar tema seleccionado o tema corporativo por defecto
        self.colors = themes.get(theme, themes['corporate'])

        # Configuración de diseño
        self.design = {
            'width': 1400,               # Ancho ampliado para mejor espaciado
            'height': 900,               # Alto amplio para mejor visualización
            'margins': {'t': 120, 'b': 100, 'l': 80, 'r': 80},
            'title_size': 28,
            'subtitle_size': 18,
            'annotation_size': 20,
            'copyright_size': 14,
            'line_width': 1.5,
            'connection_line_width': 1,
            'phase_border_width': 1.5,
            'phase_title_font_size': 22,
            'phase_desc_font_size': 16,
            'desc_outside_font_size': 14,
            'hover_font_size': 14
        }

    def _create_development_phases(self) -> List[VPhase]:
        """Crea las fases del lado izquierdo (Desarrollo)."""
        return [
            VPhase(
                name="Requisitos",
                description="Definición y validación de requerimientos",
                color=self.colors['development'][0],
                coordinates=(1, 6),
                hover_text="• Captura de requisitos<br>• Definición de alcance<br>• Análisis de viabilidad"
            ),
            VPhase(
                name="Análisis",
                description="Modelado del sistema y arquitectura",
                color=self.colors['development'][1],
                coordinates=(3, 4),
                hover_text="• Análisis funcional<br>• Modelado de procesos<br>• Especificaciones técnicas"
            ),
            VPhase(
                name="Diseño",
                description="Diseño detallado de componentes",
                color=self.colors['development'][2],
                coordinates=(5, 2),
                hover_text="• Diseño de arquitectura<br>• Diseño de interfaces<br>• Diseño de bases de datos"
            )
        ]

    def _create_implementation_phase(self) -> VPhase:
        """Crea la fase central (Implementación)."""
        return VPhase(
            name="Implementación",
            description="Codificación y construcción",
            color=self.colors['accent'],
            coordinates=(7, 0),
            width=2.8,                # Más ancho para destacar
            height=1.8,               # Más alto para destacar
            title_font_size=24,       # Fuente más grande para destacar
            desc_font_size=18,
            hover_text="• Desarrollo de código<br>• Pruebas unitarias<br>• Revisión de código<br>• Control de calidad"
        )

    def _create_validation_phases(self) -> List[VPhase]:
        """Crea las fases del lado derecho (Validación)."""
        return [
            VPhase(
                name="Verificación",
                description="Verificación contra requisitos",
                color=self.colors['validation'][0],
                coordinates=(9, 2),
                hover_text="• Revisión técnica<br>• Verificación vs requisitos<br>• Pruebas de componentes"
            ),
            VPhase(
                name="Integración",
                description="Integración y pruebas de módulos",
                color=self.colors['validation'][1],
                coordinates=(11, 4),
                hover_text="• Pruebas de integración<br>• Validación de interfaces<br>• Pruebas de subsistemas"
            ),
            VPhase(
                name="Validación",
                description="Validación completa del sistema",
                color=self.colors['validation'][2],
                coordinates=(13, 6),
                hover_text="• Pruebas de aceptación<br>• Validación de requisitos<br>• Auditoría de calidad"
            )
        ]

    def _configure_layout(self):
        """Configura el layout base del diagrama."""
        title_text = f"<b>{self.title}</b><br><span style='font-size:{self.design['subtitle_size']}px'>{self.subtitle}</span>"
        if self.company:
            title_text += f"<br><span style='font-size:{self.design['subtitle_size']}px'>{self.company}</span>"

        self.fig.update_layout(
            title={
                'text': title_text,
                'x': 0.5,
                'y': 0.98,
                'xanchor': 'center',
                'yanchor': 'top',
                'font': {
                    'size': self.design['title_size'],
                    'family': self.colors['font_family'],
                    'color': self.colors['title_color']
                }
            },
            xaxis={
                'visible': False,
                'range': [-0.5, 14.5]
            },
            yaxis={
                'visible': False,
                'range': [-1.5, 7.5]
            },
            plot_bgcolor=self.colors['bg'],
            paper_bgcolor=self.colors['bg'],
            width=self.design['width'],
            height=self.design['height'],
            margin=self.design['margins'],
            showlegend=False,
            annotations=[
                {
                    'text': self.copyright_text,
                    'showarrow': False,
                    'xref': "paper",
                    'yref': "paper",
                    'x': 0.5,
                    'y': -0.08,
                    'font': {
                        'size': self.design['copyright_size'],
                        'color': 'gray',
                        'family': self.colors['font_family']
                    }
                }
            ]
        )

        # Agregar borde exterior decorativo
        self.fig.add_shape(
            type="rect",
            xref="paper",
            yref="paper",
            x0=0,
            y0=0,
            x1=1,
            y1=1,
            line={
                'color': self.colors['primary'],
                'width': 3
            },
            fillcolor=None
        )

    def _draw_main_v_line(self):
        """Dibuja la línea principal en forma de V."""
        x_coords = [phase.coordinates[0] for phase in self.left_phases]
        y_coords = [phase.coordinates[1] for phase in self.left_phases]

        # Añadir fase central
        x_coords.append(self.central_phase.coordinates[0])
        y_coords.append(self.central_phase.coordinates[1])

        # Añadir fases derechas
        x_coords.extend([phase.coordinates[0] for phase in self.right_phases])
        y_coords.extend([phase.coordinates[1] for phase in self.right_phases])

        # Dibujar línea principal
        self.fig.add_trace(go.Scatter(
            x=x_coords,
            y=y_coords,
            mode='lines',
            line={
                'color': self.colors['line'],
                'width': self.design['line_width']
            },
            hoverinfo='skip'
        ))

    def _draw_connection_lines(self):
        """Dibuja las líneas de conexión entre fases correspondientes."""
        for i, left_phase in enumerate(self.left_phases):
            right_phase = self.right_phases[len(self.right_phases) - 1 - i]

            # Dibujar línea de correspondencia
            self.fig.add_trace(go.Scatter(
                x=[left_phase.coordinates[0], right_phase.coordinates[0]],
                y=[left_phase.coordinates[1], right_phase.coordinates[1]],
                mode='lines',
                line={
                    'color': self.colors['connection_line'],
                    'width': self.design['connection_line_width'],
                    'dash': 'dot'
                },
                hoverinfo='skip'
            ))

    def _draw_phase_box(self, phase: VPhase):
        """Dibuja una fase individual con diseño mejorado."""
        # Calcular coordenadas del cuadro
        x0 = phase.coordinates[0] - phase.width/2
        y0 = phase.coordinates[1] - phase.height/2
        x1 = phase.coordinates[0] + phase.width/2
        y1 = phase.coordinates[1] + phase.height/2

        # Dibujar rectángulo principal con borde suave
        self.fig.add_shape(
            type="rect",
            x0=x0,
            y0=y0,
            x1=x1,
            y1=y1,
            fillcolor=phase.color,
            line={
                'color': 'white',
                'width': self.design['phase_border_width']
            },
            layer='below'
        )

        # Texto del título de la fase
        self.fig.add_trace(go.Scatter(
            x=[phase.coordinates[0]],
            y=[phase.coordinates[1] + phase.height/5],  # Ligeramente arriba del centro
            mode='text',
            text=f"<b>{phase.name}</b>",
            textposition='middle center',
            textfont={
                'size': phase.title_font_size,
                'color': phase.text_color,
                'family': self.colors['font_family']
            },
            hoverinfo='text',
            hovertext=phase.hover_text if phase.hover_text else f"<b>{phase.name}</b><br>{phase.description}"
        ))

        # Texto de descripción dentro del cuadro
        self.fig.add_trace(go.Scatter(
            x=[phase.coordinates[0]],
            y=[phase.coordinates[1] - phase.height/5],  # Ligeramente abajo del centro
            mode='text',
            text=phase.description,
            textposition='middle center',
            textfont={
                'size': phase.desc_font_size,
                'color': phase.text_color,
                'family': self.colors['font_family']
            },
            hoverinfo='skip'
        ))

    def _add_section_labels(self):
        """Añade etiquetas para las secciones de Desarrollo y Validación."""
        # Etiqueta de desarrollo
        self.fig.add_annotation(
            x=3,
            y=7,
            text="<b>DESARROLLO</b>",
            showarrow=False,
            font={
                'size': self.design['annotation_size'],
                'color': self.colors['primary'],
                'family': self.colors['font_family']
            }
        )

        # Etiqueta de validación
        self.fig.add_annotation(
            x=11,
            y=7,
            text="<b>VALIDACIÓN</b>",
            showarrow=False,
            font={
                'size': self.design['annotation_size'],
                'color': self.colors['primary'],
                'family': self.colors['font_family']
            }
        )

        # Flechas de dirección
        self.fig.add_annotation(
            x=7,
            y=7,
            text="",
            showarrow=True,
            arrowhead=2,
            arrowsize=1.5,
            arrowwidth=2,
            arrowcolor=self.colors['primary'],
            ax=-120,
            ay=0
        )

        self.fig.add_annotation(
            x=7,
            y=7,
            text="",
            showarrow=True,
            arrowhead=2,
            arrowsize=1.5,
            arrowwidth=2,
            arrowcolor=self.colors['primary'],
            ax=120,
            ay=0
        )

    def generate(self):
        """Genera el diagrama completo."""
        # Dibujar líneas
        self._draw_main_v_line()
        self._draw_connection_lines()

        # Dibujar fases
        for phase in self.left_phases:
            self._draw_phase_box(phase)

        self._draw_phase_box(self.central_phase)

        for phase in self.right_phases:
            self._draw_phase_box(phase)

        # Añadir etiquetas y flechas
        self._add_section_labels()

        return self.fig

    def show(self):
        """Muestra el diagrama interactivo."""
        self.generate().show()

    def save(self, filename: str, scale: int = 2, format: str = "png"):
        """
        Guarda el diagrama como imagen.

        Args:
            filename: Nombre del archivo sin extensión
            scale: Factor de escala para la resolución (1-3)
            format: Formato de imagen (png, jpeg, svg, pdf)
        """
        full_filename = f"{filename}.{format}" if "." not in filename else filename
        self.generate().write_image(full_filename, scale=scale)

    def get_html(self):
        """Retorna el HTML para incrustar el diagrama en una página web."""
        return self.generate().to_html(include_plotlyjs=True, full_html=True)


# Ejemplo de uso con diferentes temas
if __name__ == "__main__":
    # Tema corporativo (por defecto)
    v_model_corporate = EnhancedVModelDiagram(
        title="MODELO EN V",
        subtitle="Metodología de Desarrollo y Validación",
        company="EUROLOGISTIC",
        theme="corporate"
    )
    v_model_corporate.show()

    # Tema moderno
    v_model_modern = EnhancedVModelDiagram(
        title="MODELO EN V",
        subtitle="Enfoque de Desarrollo de Software",
        company="EUROLOGISTIC",
        theme="modern"
    )
    # v_model_modern.show()

    # Tema clásico
    v_model_classic = EnhancedVModelDiagram(
        title="MODELO EN V",
        subtitle="Proceso de Desarrollo de Software",
        company="EUROLOGISTIC",
        theme="classic"
    )
    # v_model_classic.show()

    # Guardar como imagen de alta calidad
    # v_model_corporate.save("modelo_v_corporativo_hq", scale=3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 3. Conclusión
#
# El caso de estudio de EUROLOGISTIC pone de manifiesto la necesidad de abordar el desarrollo de software mediante metodologías estructuradas, especialmente en contextos de alta criticidad y cobertura global. A diferencia de los enfoques ágiles, las metodologías tradicionales proporcionan marcos sólidos para la planificación, documentación, trazabilidad y control de riesgos, todos ellos esenciales para sistemas con una elevada carga transaccional.
#
# La aplicación combinada de modelos tradicionales, como Cascada, Incremental, Espiral y el Modelo en V, permite asegurar la calidad del producto desde sus etapas iniciales hasta su implementación, promoviendo entregas progresivas, controladas y validadas. Este enfoque resulta particularmente eficaz cuando se trabaja con infraestructuras distribuidas y equipos multidisciplinarios en múltiples regiones del mundo.
#
# Asimismo, la incorporación de un ciclo profesional de aseguramiento de calidad (QA), sustentado en normas como la ISO/IEC 29119 y lineamientos de ISTQB, contribuye significativamente a la detección temprana de errores, la mejora continua y la entrega de un software confiable, escalable y alineado a los objetivos estratégicos de la organización.

# %% [markdown]
# ## 4. Bibliografía
#
# - Pressman, R. S. (2010). *Ingeniería del software: Un enfoque práctico* (7ª ed.). McGraw-Hill Education.
# - Sommerville, I. (2011). *Ingeniería del software* (9ª ed.). Pearson Educación.
# - International Organization for Standardization. (2013). *ISO/IEC 29119-1:2013 Software and systems engineering — Software testing — Part 1: Concepts and definitions*. Recuperado de [https://www.iso.org/standard/45170.html](https://www.iso.org/standard/45170.html)
# - International Software Testing Qualifications Board (ISTQB). (2023). *Foundation level syllabus*. Recuperado de [https://www.istqb.org](https://www.istqb.org)
# - Instituto Profesional IPP. (2024). *Documentación oficial Módulo 1: Metodología de Diseño de Software*. Plataforma CANVAS.
